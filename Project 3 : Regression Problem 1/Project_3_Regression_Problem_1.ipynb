# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# Load the training and testing data
test_data = pd.read_csv('/content/test.csv')
train_data = pd.read_csv('/content/train.csv')

# %%
train_data
# Out:
#            1      2      3
# 0     -7.260   9.57   5.36
# 1      3.460  10.70 -13.30
# 2    -13.000  -3.45  31.80
# 3      7.080 -14.10   2.00
# 4    -15.200 -18.60  48.80
# ...      ...    ...    ...
# 9995  17.000  -7.38 -21.80
# 9996   0.258 -19.50  22.10
# 9997  17.600  11.30 -47.80
# 9998   0.532 -15.20  20.80
# 9999  10.800  -2.72 -20.70
#
# [10000 rows x 3 columns]

# %%
test_data
# Out:
#            1      2     3
# 0     15.900  11.70 -37.6
# 1     -2.720  -4.54  11.5
# 2    -14.600  18.60  11.5
# 3      0.224  16.40 -15.2
# 4    -12.200  11.70  17.4
# ...      ...    ...   ...
# 4995 -14.400   7.06  21.4
# 4996 -12.200  12.20  15.0
# 4997 -19.200 -18.20  56.7
# 4998 -13.600   2.77  26.6
# 4999  -3.780   0.98  11.9
#
# [5000 rows x 3 columns]

# %%
# Check the structure and first few rows of the datasets
print(train_data.head())
print(test_data.head())
# Out:
#        1      2      3
# 0  -7.26   9.57   5.36
# 1   3.46  10.70 -13.30
# 2 -13.00  -3.45  31.80
# 3   7.08 -14.10   2.00
# 4 -15.20 -18.60  48.80
#         1      2     3
# 0  15.900  11.70 -37.6
# 1  -2.720  -4.54  11.5
# 2 -14.600  18.60  11.5
# 3   0.224  16.40 -15.2
# 4 -12.200  11.70  17.4

# %%
a = test_data.isnull().sum()

# %%
print("Columns with Missing Values:")
print(a[a > 0])
# Out:
# Columns with Missing Values:
# Series([], dtype: int64)

# %%
# Separate features and target variable for training and testing
X_train = train_data.iloc[:, :-1]  # Features in training data
y_train = train_data.iloc[:, -1]   # Target variable in training data

X_test = test_data.iloc[:, :-1]    # Features in testing data
y_test = test_data.iloc[:, -1]     # Target variable in testing data

# %%
# Initialize the linear regression model
model = LinearRegression()

# %%
# Train the model on the traing data
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict the target variable on the test set
predictions = model.predict(X_test)

# %%
# Calculate Mean Squared Error and Mean Absolute Error
mse = mean_squared_error(y_test, predictions)
mae = mean_absolute_error(y_test, predictions)

# %%
# Print the metrics
print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
# Out:
# Mean Squared Error: 5.049771909355411
# Mean Absolute Error: 1.7998085941558195
